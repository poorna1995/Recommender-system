# %% [markdown]
# # Recommender system
#
# Two types of Recommender system
# 1) content based  recommender sytem
# 2) collaborative recommender system

# %% [markdown]
# # Import Libraries

# %%
import numpy as np

import pandas as pd
import  matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Get the data

# %%
col_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('Desktop/u.data', sep='\t', names=col_names)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
df.columns
# Out:
# Index(['user_id', 'item_id', 'rating', 'timestamp'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 4 columns):
# user_id      100003 non-null int64
# item_id      100003 non-null int64
# rating       100003 non-null int64
# timestamp    100003 non-null int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %% [markdown]
# Now let's get the  movie  titles

# %%
movie_titles = pd.read_csv("Desktop/Movie_Id_Titles")
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %% [markdown]
# merge them together (df+movie _titles)

# %%
df=pd.merge(df,movie_titles)

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# Let's  explore the data  and look at most rated movies

# %%
import seaborn  as  sns

# %% [markdown]
# Let's create a ratings dataframe with average rating and number of ratings:

# %%
df.groupby('title')['rating'].mean().sort_values(ascending=False).head()
# Out:
# title
# Marlene Dietrich: Shadow and Light (1996)     5.0
# Prefontaine (1997)                            5.0
# Santa with Muscles (1996)                     5.0
# Star Kid (1997)                               5.0
# Someone Else's America (1995)                 5.0
# Name: rating, dtype: float64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
df.groupby('title')['rating'].count().sort_values(ascending=False).head()
# Out:
# title
# Star Wars (1977)             584
# Contact (1997)               509
# Fargo (1996)                 508
# Return of the Jedi (1983)    507
# Liar Liar (1997)             485
# Name: rating, dtype: int64

# %%
ratings = pd.DataFrame(df.groupby('title')['rating'].mean())
ratings.head()
# Out:
#                              rating
# title
# 'Til There Was You (1997)  2.333333
# 1-900 (1994)               2.600000
# 101 Dalmatians (1996)      2.908257
# 12 Angry Men (1957)        4.344000
# 187 (1997)                 3.024390

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title')['rating'].count())
ratings.head()
# Out:
#                              rating  num of ratings
# title
# 'Til There Was You (1997)  2.333333               9
# 1-900 (1994)               2.600000               5
# 101 Dalmatians (1996)      2.908257             109
# 12 Angry Men (1957)        4.344000             125
# 187 (1997)                 3.024390              41

# %%
plt.figure(figsize=(10,4))
ratings['num of ratings'].hist(bins=70)
plt.xlabel('number of ratings')
# Out:
# Text(0.5,0,'number of ratings')

# %%
sns.jointplot(x='rating',y='num of ratings',data=ratings,alpha=0.5)

# %% [markdown]
# # Recommending similar movies

# %% [markdown]
#  create a matrix that has the user ids on one axis and the movie title on another axis. Each cell will then consist of the rating the user gave to that movie. Note there will be a lot of NaN values, because most people have not seen most of the movies.

# %%
movie_sim = df.pivot_table(index='user_id',columns='title',values='rating')
movie_sim
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
# 10                             NaN           NaN                    NaN
# 11                             NaN           NaN                    NaN
# ...

# %%
ratings.sort_values('num of ratings',ascending=False).head(10)
# Out:
#                                  rating  num of ratings
# title
# Star Wars (1977)               4.359589             584
# Contact (1997)                 3.803536             509
# Fargo (1996)                   4.155512             508
# Return of the Jedi (1983)      4.007890             507
# Liar Liar (1997)               3.156701             485
# English Patient, The (1996)    3.656965             481
# Scream (1996)                  3.441423             478
# Toy Story (1995)               3.878319             452
# Air Force One (1997)           3.631090             431
# Independence Day (ID4) (1996)  3.438228             429

# %%
starwars_user_ratings = movie_sim['Star Wars (1977)']
contact_user_ratings = movie_sim['Contact (1997)']
starwars_user_ratings
# Out:
# user_id
# 0      5.0
# 1      5.0
# 2      5.0
# 3      NaN
# 4      5.0
# 5      4.0
# 6      4.0
# 7      5.0
# 8      5.0
# 9      5.0
# 10     5.0
# 11     NaN
# 12     4.0
# 13     5.0
# 14     5.0
# 15     5.0
# 16     NaN
# 17     NaN
# 18     4.0
# 19     NaN
# 20     3.0
# 21     3.0
# 22     5.0
# 23     4.0
# 24     NaN
# 25     5.0
# 26     4.0
# 27     3.0
# 28     4.0
# 29     NaN
#       ...
# 914    NaN
# 915    NaN
# 916    5.0
# 917    3.0
# 918    NaN
# 919    3.0
# 920    NaN
# 921    4.0
# 922    5.0
# 923    5.0
# 924    5.0
# 925    NaN
# 926    NaN
# 927    NaN
# 928    NaN
# 929    4.0
# 930    2.0
# 931    3.0
# 932    NaN
# 933    4.0
# 934    5.0
# 935    NaN
# 936    4.0
# 937    5.0
# 938    5.0
# 939    NaN
# 940    4.0
# 941    NaN
# 942    5.0
# 943    4.0
# Name: Star Wars (1977), Length: 944, dtype: float64

# %%
contact_user_ratings
# Out:
# user_id
# 0      NaN
# 1      5.0
# 2      3.0
# 3      2.0
# 4      5.0
# 5      NaN
# 6      2.0
# 7      4.0
# 8      5.0
# 9      NaN
# 10     NaN
# 11     5.0
# 12     NaN
# 13     4.0
# 14     NaN
# 15     3.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     4.0
# 20     NaN
# 21     4.0
# 22     5.0
# 23     5.0
# 24     4.0
# 25     5.0
# 26     3.0
# 27     NaN
# 28     5.0
# 29     NaN
#       ...
# 914    NaN
# 915    2.0
# 916    NaN
# 917    NaN
# 918    NaN
# 919    4.0
# 920    4.0
# 921    NaN
# 922    4.0
# 923    NaN
# 924    3.0
# 925    NaN
# 926    4.0
# 927    NaN
# 928    NaN
# 929    NaN
# 930    NaN
# 931    3.0
# 932    NaN
# 933    NaN
# 934    NaN
# 935    NaN
# 936    3.0
# 937    4.0
# 938    5.0
# 939    4.0
# 940    5.0
# 941    4.0
# 942    4.0
# 943    NaN
# Name: Contact (1997), Length: 944, dtype: float64

# %% [markdown]
# We can then use corrwith() method to get correlations between two pandas series:

# %%
similar_to_starwars = movie_sim.corrwith(starwars_user_ratings)
similar_to_contact = movie_sim.corrwith(contact_user_ratings)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)

# %% [markdown]
# Let's clean this by removing NaN values and using a DataFrame instead of a series:

# %%
corr_starwars = pd.DataFrame(similar_to_starwars,columns=['Correlation'])
corr_starwars.dropna(inplace=True)
corr_starwars
# Out:
#                                                     Correlation
# title
# 'Til There Was You (1997)                              0.872872
# 1-900 (1994)                                          -0.645497
# 101 Dalmatians (1996)                                  0.211132
# 12 Angry Men (1957)                                    0.184289
# 187 (1997)                                             0.027398
# 2 Days in the Valley (1996)                            0.066654
# 20,000 Leagues Under the Sea (1954)                    0.289768
# 2001: A Space Odyssey (1968)                           0.230884
# 39 Steps, The (1935)                                   0.106453
# 8 1/2 (1963)                                          -0.142977
# 8 Heads in a Duffel Bag (1997)                        -0.577350
# 8 Seconds (1994)                                      -0.755929
# A Chef in Love (1996)                                  0.868599
# Above the Rim (1994)                                  -0.645497
# ...

# %%
corr_contact = pd.DataFrame(similar_to_contact,columns=['Correlation'])
corr_contact.dropna(inplace=True)
corr_contact
# Out:
#                                                     Correlation
# title
# 'Til There Was You (1997)                              0.904534
# 101 Dalmatians (1996)                                 -0.108441
# 12 Angry Men (1957)                                    0.022265
# 187 (1997)                                             0.135512
# 2 Days in the Valley (1996)                            0.248031
# 20,000 Leagues Under the Sea (1954)                    0.052442
# 2001: A Space Odyssey (1968)                           0.014245
# 39 Steps, The (1935)                                  -0.538617
# 8 1/2 (1963)                                          -0.076123
# A Chef in Love (1996)                                  0.203005
# Above the Rim (1994)                                   0.845154
# Absolute Power (1997)                                  0.165719
# Abyss, The (1989)                                      0.217310
# Ace Ventura: Pet Detective (1994)                      0.195248
# ...

# %%
corr_starwars.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                     Correlation
# title
# Hollow Reed (1996)                                          1.0
# Stripes (1981)                                              1.0
# Star Wars (1977)                                            1.0
# Man of the Year (1995)                                      1.0
# Beans of Egypt, Maine, The (1994)                           1.0
# Safe Passage (1994)                                         1.0
# Old Lady Who Walked in the Sea, The (Vieille qu...          1.0
# Outlaw, The (1943)                                          1.0
# Line King: Al Hirschfeld, The (1996)                        1.0
# Hurricane Streets (1998)                                    1.0

# %%
corr_contact.sort_values('Correlation',ascending=False).head(10)
# Out:
#                                                   Correlation
# title
# Lamerica (1994)                                           1.0
# Wedding Gift, The (1994)                                  1.0
# Visitors, The (Visiteurs, Les) (1993)                     1.0
# King of the Hill (1993)                                   1.0
# Contact (1997)                                            1.0
# Gold Diggers: The Secret of Bear Mountain (1995)          1.0
# For Ever Mozart (1996)                                    1.0
# Faust (1994)                                              1.0
# Fausto (1993)                                             1.0
# Innocent Sleep, The (1995)                                1.0

# %% [markdown]
# Let's fix this by filtering out movies that have less than 100 reviews (this value was chosen based off the histogram from earlier).

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
#                            Correlation  num of ratings
# title
# 'Til There Was You (1997)     0.872872               9
# 1-900 (1994)                 -0.645497               5
# 101 Dalmatians (1996)         0.211132             109
# 12 Angry Men (1957)           0.184289             125
# 187 (1997)                    0.027398              41

# %% [markdown]
# Now sort the values and notice how the titles make a lot more sense:

# %%
corr_contact = corr_contact.join(ratings['num of ratings'])
corr_starwars[corr_starwars['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                                                     Correlation  \
# title
# Star Wars (1977)                                       1.000000
# Empire Strikes Back, The (1980)                        0.748353
# Return of the Jedi (1983)                              0.672556
# Raiders of the Lost Ark (1981)                         0.536117
# Austin Powers: International Man of Mystery (1997)     0.377433
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130

# %%
corr_contact = pd.DataFrame(similar_to_contact,columns=['Correlation'])
corr_contact.dropna(inplace=True)
corr_contact = corr_contact.join(ratings['num of ratings'])
corr_contact[corr_contact['num of ratings']>100].sort_values('Correlation',ascending=False).head()
# Out:
#                      Correlation  num of ratings
# title
# Contact (1997)          1.000000             509
# Philadelphia (1993)     0.446509             137
# Mask, The (1994)        0.418328             129
# Young Guns (1988)       0.388839             101
# Sling Blade (1996)      0.384840             136
